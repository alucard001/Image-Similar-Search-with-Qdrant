# %% [markdown]
# ### Install necessary libraries

# %%
# !pip install opencv-python
# !pip install opencv-python-headless
# !pip install tqdm
# !pip install ipyplot
# !pip install qdrant-client

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models
from qdrant_client.http.models import Filter, FieldCondition, VectorParams, MatchValue
import cv2
import numpy as np
import os
import ipyplot

# %% [markdown]
# ### Use `QdrantClient` to connect to your Qdrant server.
#
# I did not use `:memory:`, but I setup a docker container for that.
#
# Here is the command to create docker
#
# `docker run -p 6333:6333 -p 6334:6334  -v $(pwd)/qdrant_storage:/qdrant/storage:z qdrant/qdrant`

# %%
qdrant_client = QdrantClient(host="localhost", port=6333, prefer_grpc=True)

# %% [markdown]
# ### Create a new collection called 'animals' if it does not exists
#
# About the `size` of the vector: When the next block of code use `224*224` as image size, I suspect that the `size` parameter should also be `224*224`.

# %%
first_collection = qdrant_client.recreate_collection(
    collection_name="animals",
    vectors_config=models.VectorParams(
        size=224*224, distance=models.Distance.COSINE
    )
)

# %% [markdown]
# ### Convert image to vector
#
# Actually there seems to be quite a few 3rd parties API, including OpenAI, available for image embedding.  I did not use it.
#
# The reason is that, sometimes the images are sensitive enough (e.g. including PII) to **NOT** to dispose/send to 3rd parties.  In order to cater for this scenario, I would rather using CV2 to create embedded images.

# %%
def preprocess_image(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Resize the image to a fixed size (optional)
    resized_image = cv2.resize(image, (224, 224))

    # Convert the image to grayscale (optional)
    gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

    # Normalize the pixel values
    normalized_image = cv2.normalize(
        gray_image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

    # Flatten the image into a 1D array
    flattened_image = normalized_image.flatten()

    return flattened_image

# %% [markdown]
# ### Loop through and embed images
#
# I use the [animal data in Kaggle](https://www.kaggle.com/datasets/iamsouravbanerjee/animal-image-dataset-90-different-animals).
#
# The full animal directory path would look like this:
#
# `./archive/animals/dog/4aacd195b5.jpg`

# %%
animal_directory = "archive/animals"

id = 0

for animal_type in os.listdir(animal_directory):
    # if animal_type is cat, dog or fox, the process
    if animal_type not in ["cat", "dog", "fox"]:
        continue

    animal_type_directory = os.path.join(animal_directory, animal_type)

    for image_file in os.listdir(animal_type_directory):
        image_path = os.path.join(animal_type_directory, image_file)

        # Preprocess the image and get the embedding
        embedding = preprocess_image(image_path)

        id += 1

        # Add the embedding to Qdrant
        qdrant_client.upsert(
            collection_name="animals",
            points=[
                models.PointStruct(
                    id = id,
                    vector = embedding,
                    payload = {
                        "animal_type": animal_type,
                        "image_file": image_file
                    },
                )
            ]
        )

# %% [markdown]
# ### Now create the search request to Qdrant
#
# Actually [the documentation from Qdrant on Python](https://python-client.qdrant.tech/qdrant_client.http.models.models) is very difficult to read.  So if you don't understand their doc, that's OK.
#
# You can refer to [another Qdrant example](https://colab.research.google.com/github/qdrant/examples/blob/master/qdrant_101_getting_started/getting_started.ipynb#scrollTo=5-Z4LbHE4lws) to find out how different functions work

# %%
# Create search request
# https://python-client.qdrant.tech/qdrant_client.http.models.models

# search_image = os.path.join(animal_directory, 'dog', '2a8a6a6050.jpg')
search_image = os.path.join(animal_directory, 'dog', '4aacd195b5.jpg')

result = qdrant_client.search(
    collection_name="animals",
    query_vector=preprocess_image(search_image),
    query_filter=Filter(
        must=[
            FieldCondition(
                key="animal_type",
                match=MatchValue(
                    value="dog"
                )
            )
        ]
    ),
    limit=10,
    with_payload=True,
    score_threshold=0,
)

# %% [markdown]
# ### Then, show the original search image

# %%
ipyplot.plot_images([search_image], img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BRq9HYGPU8etjmu5ZbRc7z {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BRq9HYGPU8etjmu5ZbRc7z {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BRq9HYGPU8etjmu5ZbRc7z {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BRq9HYGPU8etjmu5ZbRc7z:checked ~ #ipyplot-html-viewer-textarea-BRq9HYGPU8etjmu5ZbRc7z {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BRq9HYGPU8etjmu5ZbRc7z:checked + #ipyplot-html-viewer-label-BRq9HYGPU8etjmu5ZbRc7z:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-BRq9HYGPU8etjmu5ZbRc7z">
#         <label id="ipyplot-html-viewer-label-BRq9HYGPU8etjmu5ZbRc7z" for="ipyplot-html-viewer-toggle-BRq9HYGPU8etjmu5ZbRc7z">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-BRq9HYGPU8etjmu5ZbRc7z" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-7BZLdCyHt3Un9UpsixvZXN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7BZLdCyHt3Un9UpsixvZXN {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7BZLdCyHt3Un9UpsixvZXN">
#     <div class="ipyplot-placeholder-div-7BZLdCyHt3Un9UpsixvZXN">
#         <div id="ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN-KfVLPmMNfupaVpVmXkJ9bY" class="ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN-KfVLPmMNfupaVpVmXkJ9bY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-7BZLdCyHt3Un9UpsixvZXN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7BZLdCyHt3Un9UpsixvZXN {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7BZLdCyHt3Un9UpsixvZXN">
#     <div class="ipyplot-placeholder-div-7BZLdCyHt3Un9UpsixvZXN">
#         <div id="ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN-KfVLPmMNfupaVpVmXkJ9bY" class="ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7BZLdCyHt3Un9UpsixvZXN-KfVLPmMNfupaVpVmXkJ9bY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### Now show the result of the search, look good to me

# %%
all_imgs = []
all_img_files = []
for file in result:
    # print(file)
    image_path = os.path.join(animal_directory, file.payload['animal_type'], file.payload['image_file'])
    all_imgs.append(image_path)
    all_img_files.append(file.payload['image_file'])

ipyplot.plot_images(all_imgs, all_img_files, img_width=300, )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QJMmhd7gA5yGKJmPFshDq3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QJMmhd7gA5yGKJmPFshDq3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QJMmhd7gA5yGKJmPFshDq3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QJMmhd7gA5yGKJmPFshDq3:checked ~ #ipyplot-html-viewer-textarea-QJMmhd7gA5yGKJmPFshDq3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QJMmhd7gA5yGKJmPFshDq3:checked + #ipyplot-html-viewer-label-QJMmhd7gA5yGKJmPFshDq3:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QJMmhd7gA5yGKJmPFshDq3">
#         <label id="ipyplot-html-viewer-label-QJMmhd7gA5yGKJmPFshDq3" for="ipyplot-html-viewer-toggle-QJMmhd7gA5yGKJmPFshDq3">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QJMmhd7gA5yGKJmPFshDq3" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-gDq49pQhoGH5j98LHaSJ8s {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gDq49pQhoGH5j98LHaSJ8s">
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-cTH27bG39gNV6Rvhjv8ZPB" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4aacd195b5.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-cTH27bG39gNV6Rvhjv8ZPB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-aoXz9iMeRosn5rcz5kcf7U" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">084a6888d7.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/084a6888d7.jpg</h4><img src="archive/animals/dog/084a6888d7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-aoXz9iMeRosn5rcz5kcf7U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-MhsibFzbSB4eJAVoa5DhcH" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2a74dd288c.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/2a74dd288c.jpg</h4><img src="archive/animals/dog/2a74dd288c.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-MhsibFzbSB4eJAVoa5DhcH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-XnXbzVhrTQMyeuwPCQiRMp" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">05b151f72d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/05b151f72d.jpg</h4><img src="archive/animals/dog/05b151f72d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-XnXbzVhrTQMyeuwPCQiRMp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-gC8ZavWrng9oYU8y5zoMM6" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">23c5c07d8d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/23c5c07d8d.jpg</h4><img src="archive/animals/dog/23c5c07d8d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-gC8ZavWrng9oYU8y5zoMM6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-HcVFwgpLYvwVTgpdfQzfvt" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6afa462776.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">arch
#         <style>
#         #ipyplot-imgs-container-div-gDq49pQhoGH5j98LHaSJ8s {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gDq49pQhoGH5j98LHaSJ8s">
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-cTH27bG39gNV6Rvhjv8ZPB" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4aacd195b5.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-cTH27bG39gNV6Rvhjv8ZPB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-aoXz9iMeRosn5rcz5kcf7U" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">084a6888d7.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/084a6888d7.jpg</h4><img src="archive/animals/dog/084a6888d7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-aoXz9iMeRosn5rcz5kcf7U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-MhsibFzbSB4eJAVoa5DhcH" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2a74dd288c.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/2a74dd288c.jpg</h4><img src="archive/animals/dog/2a74dd288c.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-MhsibFzbSB4eJAVoa5DhcH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-XnXbzVhrTQMyeuwPCQiRMp" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">05b151f72d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/05b151f72d.jpg</h4><img src="archive/animals/dog/05b151f72d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-XnXbzVhrTQMyeuwPCQiRMp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-gC8ZavWrng9oYU8y5zoMM6" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">23c5c07d8d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/23c5c07d8d.jpg</h4><img src="archive/animals/dog/23c5c07d8d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-gC8ZavWrng9oYU8y5zoMM6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-HcVFwgpLYvwVTgpdfQzfvt" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6afa462776.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/6afa462776.jpg</h4><img src="archive/animals/dog/6afa462776.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-HcVFwgpLYvwVTgpdfQzfvt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-bo88PNb93UvhxTQKDqLtJa" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">024a037366.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/024a037366.jpg</h4><img src="archive/animals/dog/024a037366.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-bo88PNb93UvhxTQKDqLtJa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDq49pQhoGH5j98LHaSJ8s">
#         <div id="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s-R9JbaAenvzFoPvEQBiLKvQ" class="ipyplot-content-div-gDq49pQhoGH5j98LHaSJ8s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3fb7d7c4ef.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal

# %% [markdown]
# ### How about using `DOT` as algorithm for distance finding?
#
# Let's duplicate the code and wrap it as a helper function to test

# %%
def create_and_add_vectors(collection_name, distance):
    first_collection = qdrant_client.recreate_collection(
        collection_name=collection_name,
        vectors_config=models.VectorParams(
            size=224*224, distance=distance
        )
    )

    animal_directory = "archive/animals"

    id = 0

    for animal_type in os.listdir(animal_directory):
        # if animal_type is cat, dog or fox, the process
        if animal_type not in ["cat", "dog", "fox"]:
            continue

        animal_type_directory = os.path.join(animal_directory, animal_type)

        for image_file in os.listdir(animal_type_directory):
            image_path = os.path.join(animal_type_directory, image_file)

            # Preprocess the image and get the embedding
            embedding = preprocess_image(image_path)

            id += 1

            # Add the embedding to Qdrant
            qdrant_client.upsert(
                collection_name=collection_name,
                points=[
                    models.PointStruct(
                        id = id,
                        vector = embedding,
                        payload = {
                            "animal_type": animal_type,
                            "image_file": image_file
                        },
                    )
                ]
            )

# %% [markdown]
# #### Do the magic

# %%
create_and_add_vectors('animals_dot', models.Distance.DOT)

# %% [markdown]
# #### Create the search request, using the new collection
#
# Looks...reasonable?

# %%
# Create search request
# https://python-client.qdrant.tech/qdrant_client.http.models.models

# search_image = os.path.join(animal_directory, 'dog', '2a8a6a6050.jpg')
search_image = os.path.join(animal_directory, 'dog', '4aacd195b5.jpg')

result = qdrant_client.search(
    collection_name="animals_dot",  # <==== Change the collection
    query_vector=preprocess_image(search_image),
    query_filter=Filter(
        must=[
            FieldCondition(
                key="animal_type",
                match=MatchValue(
                    value="dog"
                )
            )
        ]
    ),
    limit=10,
    with_payload=True,
    score_threshold=0,
)

# Display the search results.  This block of code is duplicated for demo purpose
all_imgs = []
all_img_files = []
for file in result:
    # print(file)
    image_path = os.path.join(
        animal_directory, file.payload['animal_type'], file.payload['image_file'])
    all_imgs.append(image_path)
    all_img_files.append(file.payload['image_file'])

# Show Original image
ipyplot.plot_images([search_image], img_width=400)

# Show search result
ipyplot.plot_images(all_imgs, all_img_files, img_width=300, )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Ao7uJxZaTrG2jTcKfF8DMH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Ao7uJxZaTrG2jTcKfF8DMH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Ao7uJxZaTrG2jTcKfF8DMH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Ao7uJxZaTrG2jTcKfF8DMH:checked ~ #ipyplot-html-viewer-textarea-Ao7uJxZaTrG2jTcKfF8DMH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Ao7uJxZaTrG2jTcKfF8DMH:checked + #ipyplot-html-viewer-label-Ao7uJxZaTrG2jTcKfF8DMH:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Ao7uJxZaTrG2jTcKfF8DMH">
#         <label id="ipyplot-html-viewer-label-Ao7uJxZaTrG2jTcKfF8DMH" for="ipyplot-html-viewer-toggle-Ao7uJxZaTrG2jTcKfF8DMH">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Ao7uJxZaTrG2jTcKfF8DMH" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-EzCzBDmMwPThSbVD92N7g9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EzCzBDmMwPThSbVD92N7g9 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EzCzBDmMwPThSbVD92N7g9">
#     <div class="ipyplot-placeholder-div-EzCzBDmMwPThSbVD92N7g9">
#         <div id="ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9-cJsqsySM2PEgNSqkjRjjRP" class="ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9-cJsqsySM2PEgNSqkjRjjRP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-EzCzBDmMwPThSbVD92N7g9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EzCzBDmMwPThSbVD92N7g9 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EzCzBDmMwPThSbVD92N7g9">
#     <div class="ipyplot-placeholder-div-EzCzBDmMwPThSbVD92N7g9">
#         <div id="ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9-cJsqsySM2PEgNSqkjRjjRP" class="ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzCzBDmMwPThSbVD92N7g9-cJsqsySM2PEgNSqkjRjjRP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-3EKDBWFxYg9r4SCrA7ypG6 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3EKDBWFxYg9r4SCrA7ypG6 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3EKDBWFxYg9r4SCrA7ypG6 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3EKDBWFxYg9r4SCrA7ypG6:checked ~ #ipyplot-html-viewer-textarea-3EKDBWFxYg9r4SCrA7ypG6 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3EKDBWFxYg9r4SCrA7ypG6:checked + #ipyplot-html-viewer-label-3EKDBWFxYg9r4SCrA7ypG6:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-3EKDBWFxYg9r4SCrA7ypG6">
#         <label id="ipyplot-html-viewer-label-3EKDBWFxYg9r4SCrA7ypG6" for="ipyplot-html-viewer-toggle-3EKDBWFxYg9r4SCrA7ypG6">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-3EKDBWFxYg9r4SCrA7ypG6" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-eiXhYTBhxn2ZcYWrTUio7Z {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-eiXhYTBhxn2ZcYWrTUio7Z">
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-N5ArM89oW3YW2GwNrxPVbC" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">23c5c07d8d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/23c5c07d8d.jpg</h4><img src="archive/animals/dog/23c5c07d8d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-N5ArM89oW3YW2GwNrxPVbC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-BYrbKTVUFsy2QDLvT4gXG3" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">024a037366.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/024a037366.jpg</h4><img src="archive/animals/dog/024a037366.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-BYrbKTVUFsy2QDLvT4gXG3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-9xjh2fcsFUPgp6MWNv4Cjp" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6afa462776.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/6afa462776.jpg</h4><img src="archive/animals/dog/6afa462776.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-9xjh2fcsFUPgp6MWNv4Cjp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-R8sb9E27FaoYfXCHGhdWRX" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7a42ed2c8d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/7a42ed2c8d.jpg</h4><img src="archive/animals/dog/7a42ed2c8d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-R8sb9E27FaoYfXCHGhdWRX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-nChSUjQhaEMts899nfEWMB" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9bd48a19a4.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/9bd48a19a4.jpg</h4><img src="archive/animals/dog/9bd48a19a4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-nChSUjQhaEMts899nfEWMB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-ctXVCJJrT3nkLxQhKvEdkm" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7ca88b95e5.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">arch
#         <style>
#         #ipyplot-imgs-container-div-eiXhYTBhxn2ZcYWrTUio7Z {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-eiXhYTBhxn2ZcYWrTUio7Z">
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-N5ArM89oW3YW2GwNrxPVbC" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">23c5c07d8d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/23c5c07d8d.jpg</h4><img src="archive/animals/dog/23c5c07d8d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-N5ArM89oW3YW2GwNrxPVbC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-BYrbKTVUFsy2QDLvT4gXG3" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">024a037366.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/024a037366.jpg</h4><img src="archive/animals/dog/024a037366.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-BYrbKTVUFsy2QDLvT4gXG3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-9xjh2fcsFUPgp6MWNv4Cjp" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6afa462776.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/6afa462776.jpg</h4><img src="archive/animals/dog/6afa462776.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-9xjh2fcsFUPgp6MWNv4Cjp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-R8sb9E27FaoYfXCHGhdWRX" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7a42ed2c8d.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/7a42ed2c8d.jpg</h4><img src="archive/animals/dog/7a42ed2c8d.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-R8sb9E27FaoYfXCHGhdWRX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-nChSUjQhaEMts899nfEWMB" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9bd48a19a4.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/9bd48a19a4.jpg</h4><img src="archive/animals/dog/9bd48a19a4.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-nChSUjQhaEMts899nfEWMB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-ctXVCJJrT3nkLxQhKvEdkm" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7ca88b95e5.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/7ca88b95e5.jpg</h4><img src="archive/animals/dog/7ca88b95e5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-ctXVCJJrT3nkLxQhKvEdkm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-QUPGaqpzWnVFiRQBKiZvhY" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4aacd195b5.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-QUPGaqpzWnVFiRQBKiZvhY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-eiXhYTBhxn2ZcYWrTUio7Z">
#         <div id="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z-FWip9o3M3pqNzqF9X8Yfbt" class="ipyplot-content-div-eiXhYTBhxn2ZcYWrTUio7Z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">36c2df0788.jpg</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal

# %% [markdown]
# ### Let's do it again with `EUCLID`

# %%
create_and_add_vectors('animals_euclid', models.Distance.EUCLID)

# %% [markdown]
# And let's duplicate everything, and
#
# Yes, you saw that right, there is no result!

# %%
# Create search request
# https://python-client.qdrant.tech/qdrant_client.http.models.models

search_image = os.path.join(animal_directory, 'dog', '4aacd195b5.jpg')

result = qdrant_client.search(
    collection_name="animals_euclid",  # <==== Change the collection
    query_vector=preprocess_image(search_image),
    query_filter=Filter(
        must=[
            FieldCondition(
                key="animal_type",
                match=MatchValue(
                    value="dog"
                )
            )
        ]
    ),
    limit=10,
    with_payload=True,
    score_threshold=0,
)

# Display the search results.  This block of code is duplicated for demo purpose
all_imgs = []
all_img_files = []
for file in result:
    # print(file)
    image_path = os.path.join(
        animal_directory, file.payload['animal_type'], file.payload['image_file'])
    all_imgs.append(image_path)
    all_img_files.append(file.payload['image_file'])

# Show Original image
ipyplot.plot_images([search_image], img_width=400)

# Show search result
# ipyplot.plot_images(all_imgs, img_width=300)
print(all_imgs)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WkpEWyy6QbdG6bJgkTigZG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WkpEWyy6QbdG6bJgkTigZG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WkpEWyy6QbdG6bJgkTigZG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WkpEWyy6QbdG6bJgkTigZG:checked ~ #ipyplot-html-viewer-textarea-WkpEWyy6QbdG6bJgkTigZG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WkpEWyy6QbdG6bJgkTigZG:checked + #ipyplot-html-viewer-label-WkpEWyy6QbdG6bJgkTigZG:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-WkpEWyy6QbdG6bJgkTigZG">
#         <label id="ipyplot-html-viewer-label-WkpEWyy6QbdG6bJgkTigZG" for="ipyplot-html-viewer-toggle-WkpEWyy6QbdG6bJgkTigZG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-WkpEWyy6QbdG6bJgkTigZG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-keUnmJd7GA77bosLYLA9yn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-keUnmJd7GA77bosLYLA9yn {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-keUnmJd7GA77bosLYLA9yn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-keUnmJd7GA77bosLYLA9yn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-keUnmJd7GA77bosLYLA9yn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-keUnmJd7GA77bosLYLA9yn">
#     <div class="ipyplot-placeholder-div-keUnmJd7GA77bosLYLA9yn">
#         <div id="ipyplot-content-div-keUnmJd7GA77bosLYLA9yn-2FrzSFxsyGGZLzJZWE3KP2" class="ipyplot-content-div-keUnmJd7GA77bosLYLA9yn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-keUnmJd7GA77bosLYLA9yn-2FrzSFxsyGGZLzJZWE3KP2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-keUnmJd7GA77bosLYLA9yn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-keUnmJd7GA77bosLYLA9yn {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-keUnmJd7GA77bosLYLA9yn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-keUnmJd7GA77bosLYLA9yn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-keUnmJd7GA77bosLYLA9yn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-keUnmJd7GA77bosLYLA9yn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-keUnmJd7GA77bosLYLA9yn">
#     <div class="ipyplot-placeholder-div-keUnmJd7GA77bosLYLA9yn">
#         <div id="ipyplot-content-div-keUnmJd7GA77bosLYLA9yn-2FrzSFxsyGGZLzJZWE3KP2" class="ipyplot-content-div-keUnmJd7GA77bosLYLA9yn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-keUnmJd7GA77bosLYLA9yn-2FrzSFxsyGGZLzJZWE3KP2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# []

# %% [markdown]
# ### Let's do it again with `MANHATTAN`

# %%
create_and_add_vectors('animals_manhattan', models.Distance.MANHATTAN)

# %% [markdown]
# And let's duplicate everything, and
#
# Yes, you saw that right, there is no result!

# %%
# Create search request
# https://python-client.qdrant.tech/qdrant_client.http.models.models

search_image = os.path.join(animal_directory, 'dog', '4aacd195b5.jpg')

result = qdrant_client.search(
    collection_name="animals_manhattan",  # <==== Change the collection
    query_vector=preprocess_image(search_image),
    query_filter=Filter(
        must=[
            FieldCondition(
                key="animal_type",
                match=MatchValue(
                    value="dog"
                )
            )
        ]
    ),
    limit=10,
    with_payload=True,
    score_threshold=0,
)

# Display the search results.  This block of code is duplicated for demo purpose
all_imgs = []
all_img_files = []
for file in result:
    # print(file)
    image_path = os.path.join(
        animal_directory, file.payload['animal_type'], file.payload['image_file'])
    all_imgs.append(image_path)
    all_img_files.append(file.payload['image_file'])

# Show Original image
ipyplot.plot_images([search_image], img_width=400)

# Show search result
# ipyplot.plot_images(all_imgs, img_width=300)
print(all_imgs)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7NRSDFBXLuYzfGHZy9pCwL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7NRSDFBXLuYzfGHZy9pCwL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7NRSDFBXLuYzfGHZy9pCwL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7NRSDFBXLuYzfGHZy9pCwL:checked ~ #ipyplot-html-viewer-textarea-7NRSDFBXLuYzfGHZy9pCwL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7NRSDFBXLuYzfGHZy9pCwL:checked + #ipyplot-html-viewer-label-7NRSDFBXLuYzfGHZy9pCwL:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-7NRSDFBXLuYzfGHZy9pCwL">
#         <label id="ipyplot-html-viewer-label-7NRSDFBXLuYzfGHZy9pCwL" for="ipyplot-html-viewer-toggle-7NRSDFBXLuYzfGHZy9pCwL">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-7NRSDFBXLuYzfGHZy9pCwL" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-PGivA7Gt7ZjhWaHZLssyBf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-PGivA7Gt7ZjhWaHZLssyBf {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-PGivA7Gt7ZjhWaHZLssyBf">
#     <div class="ipyplot-placeholder-div-PGivA7Gt7ZjhWaHZLssyBf">
#         <div id="ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf-CTPGkjEYkt6LJfbSnQNGGs" class="ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf-CTPGkjEYkt6LJfbSnQNGGs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-PGivA7Gt7ZjhWaHZLssyBf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-PGivA7Gt7ZjhWaHZLssyBf {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-PGivA7Gt7ZjhWaHZLssyBf">
#     <div class="ipyplot-placeholder-div-PGivA7Gt7ZjhWaHZLssyBf">
#         <div id="ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf-CTPGkjEYkt6LJfbSnQNGGs" class="ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">archive/animals/dog/4aacd195b5.jpg</h4><img src="archive/animals/dog/4aacd195b5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PGivA7Gt7ZjhWaHZLssyBf-CTPGkjEYkt6LJfbSnQNGGs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# []
